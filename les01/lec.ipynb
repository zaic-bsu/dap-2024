# %% [markdown]
# # Введение в анализ данных.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Обределение анализа данных
#  * область математики и информатики, занимающаяся построением и исследованием наиболее общих математических методов и вычислительных алгоритмов извлечения знаний из экспериментальных (в широком смысле) данных;
#
#  * процесс исследования, фильтрации, преобразования и моделирования данных с целью извлечения полезной информации и принятия решений.

# %% [markdown]
# ### Процесс анализа данных
#
# ![image.png](data:image/png;base64,...)
#
# * **Определение проблемы или выдвижение идей** - первый этап процесса анализа данных - определить, что вы хотите выяснить. Часто его называют *выдвижение идей*, мы формулируем идеи по поводц того, что мы хотим сделать и доказать. Идея в целом связана с гипотизой о наличии тех или иных структур данных, которые мы можем использовать для принятия решения.
#
# * **Извлечение или сбор данных** - данный могут быть собраны внутри огранизации для которой производиться анализ или могут быть получены от внешних поставщиков. Как правило на данном этапе данные явлются "сырыми". Это значит, что данные могут быть неправильно сформированы, записаны в разных форматах и содержать ошибки.
#
# * **Подготовка даннных** - на этом этапе мы подготавливаем исходные данные для проведения дальнейшего исследования. Часто подготовка является весьма интересным и сложным этапом анализа данных. Как правило, все проблемы, связанные с данными, связаны с качеством этих данных.
#
# * **Исследование и визуализация данных** - этап исследование данных подразумевает изучение данных, чтобы попытаться открыть какие-то закономерности в данных. Исследование может включать в себя различные задачи, например:
#   - Изучение того, как переменные связаны друг с другом
#   - Анализ распределения данных
#   - Обнаружение и исключение выбросов
#   - Создание быстрых визуализаций
#   - Быстрое создание новых представлений данных или моделей для последующего использования в ходе моделирования
#
# * **Предсказательная модель** - данном формализируются открытия, найденные в ходе исследования данных. Для этого закономерностям, обнаруженным в данных и позволяющим извлечь из данных содержательный смысл, нужно дать ясную интерпретацию. Итогом становится модель (model), позволяющая выразить обнаруженные закономерности. Эти модели полезны для понимания изучаемой системы и используются в двух направлениях.
#
#   - предсказания о значениях данных, которые создает система. В этом случае речь идет о регрессионных моделях.
#
#   - классификация новых продуктов. Это уже модели классификации или модели кластерного анализа.
#
# * **Проверка модели** - на этом этапе производиться проверка модели, построенной на основе начальных данных. Он важен, потому что позволяет узнать достоверность данных, созданных моделью, сравнив их с реальной системой. Как правило, при использовании данных для построения модели вы будете воспринимать их как тренировочный набор данных, а для проверки — как валидационный набор данных.
#
# * **Развертывание** - финальный шаг процесса анализа, задача которого — предоставить результаты, то есть выводы анализа. В процессе развертывания бизнес-среды анализ является выгодой, которую получит клиент, заказавший анализ.

# %% [markdown]
# ## Типы данных

# %% [markdown]
# * **Структурированные данные** - это тип данных, при котором последние упорядочены в вертикальные столбцы (поля) и горизонтальные строки (записи или наблюдения). Примером таких данных являются данные в реляционных базах и электронных таблицах. Структурированные данные зависят от модели данных, которая представляет собой определенную структуру, содержательного смысла данных и часто от способа обработки данных. Сюда входит идентификация типа данных (целое число, число с плавающей точкой, строка и т.д.) и ограничения, накладываемые на данные, например, количество символов, максимальное и минимальное значения, или ограничение на определенный набор значений.
#
# * **Неструктурированные данные** - это данные, которые не имеют определенной структуры, не предполагают наличия заранее определенных столбцов определенного
# типа.Примером неструктурированных данных могут быть такие виды информации, как фотографии и графические изображения, видеоролики, потоковые данные датчиков, веб-страницы, PDF-файлы, презентации PowerPoint, электронные письма, записи в блогах, страницы Википедии и документы Word.
#
# * **Полуструктурированные данные** - Полуструктурированные данные занимают промежуточное положение между неструктурированными и структурированными данными. Их можно рассматривать как тип структурированных данных, у которых нет строгой структуры моделей данных. Формат JSON - это пример полуструктурированных данных. Хотя хороший JSON-файл будет иметь определенный формат, здесь нет определенной схемы данных, которая всегда строго соблюдаются.

# %% [markdown]
# ## Инструмены анализа данных

# %% [markdown]
# * [**Python**](https://www.python.org/) - мультипарадигмальный высокоуровневый язык программирования общего назначения с динамической строгой типизацией и автоматическим управлением памятью, ориентированный на повышение производительности разработчика, читаемости кода и его качества, а также на обеспечение переносимости написанных на нём программ.
#
# * [**Jupyter Notebook**](https://jupyter.org/) - интерактивный блокнот, первоначально являвшийся веб-реализацией и развитием IPython, ставший самостоятельным проектом, ориентированным на работу со множеством сред выполнения.
# * **Базы данных** - упорядоченный набор структурированной информации или данных, которые обычно хранятся в электронном виде в компьютерной системе.
# * **Библиотеки**
#
# | Библиотека  | Этап анализа данных  | Описание |
# |---|---|---|
# | [IPython](https://ipython.org/)  | Извлечение и сбор данных   | Оболочка для интерактивного выполнения и распространения кода |
# | [NumPy](https://numpy.org/)  |  Подготовка даннных | Добавляет поддержку больших многомерных массивов и матриц, а также большую коллекцию математических функций высокого уровня для работы с ними  |
# | [SciPy](https://scipy.org/) | Исследование и визуализация данных | Библиотека для общих научных вычислительных задач |
# | [Pandas](https://pandas.pydata.org/)  |  Исследование и визуализация данных |Предоставляет специальные структуры данных и операции для манипулирования числовыми таблицами и временны́ми рядами  |
# | [Matplotlib](https://matplotlib.org/)  |  Исследование и визуализация данных | Визуализации данных двумерной и трёхмерной графикой  |
# | [scikit-learn ](https://scikit-learn.org) |  Предсказательная модель | Машинное обучение |

# %% [markdown]
# ## Огранизация среды для анализа данных

# %% [markdown]
# Облачные среды для анализа данных
# * [Google Colab](https://colab.research.google.com)
#
#     Google Colab — это бесплатная среда для разработки и выполнения программного кода в облаке. Она предоставляет возможность писать и запускать код на языке Python, используя только браузер, без установки специальных программ на компьютер.
#
#     Google Colab основан на Jupyter Notebook, популярном ПО для написания и запуска кода. Он поддерживает интерактивное программирование. Код можно писать в отдельных ячейках и выполнять их по порядку, просматривая результаты выполнения после блока с кодом.
#
#     В Colab можно использовать различные библиотеки Python, включая популярные библиотеки для анализа данных и машинного обучения: NumPy, Pandas и TensorFlow. Также можно загружать и обрабатывать свои данные или работать с данными из интернета.
#
# * [Kaggle](https://www.kaggle.com/)
#
#     Cистема организации конкурсов по исследованию данных, а также социальная сеть специалистов по обработке данных и машинному обучению.

# %% [markdown]
# Локальные среды для анализа данных
# * [Anaconda](https://www.anaconda.com/) -  дистрибутив языков программирования Python и R, включающий набор популярных свободных библиотек, объединённых проблематиками науки о данных и машинного обучения. Основная цель — поставка единым согласованным комплектом наиболее востребованных соответствующим кругом пользователей тематических модулей (таких как NumPy, SciPy, Astropy и других) с разрешением возникающих зависимостей и конфликтов, которые неизбежны при одиночной установке. Для управления зависимостями используется пакетный менеджер **conda**.
#
# * Среда на основе стандартных инструментов Python - среда но основе виртуального окружения и стандартного пакетного менеждера **pip**.
#
# * Среда на онове Dev Containers - среда на основе **docker** контейнера, позволяет использовать контейнер в качестве полнофункционального среда разработки. Его можно использовать для запуска приложения, для разделения инструментов, библиотек или сред выполнения. необходим для работы с базой кода, а также для помощи в непрерывной интеграции и тестировании. Для управления зависимоятми используется пакетный менеджер **pip**.

# %% [markdown]
# ## Jupyter Notebook

# %% [markdown]
# ### Markdown (текстовы) ячейки

# %% [markdown]
# #### Заголовки
# ``` markdown
# # Заголовок 1 уровня
# ## Заголовок 2 уровня
# ### Заголовок 3 уровня
# #### Заголовок 4 уровня
# ##### Заголовок 5 уровня
# ###### Заголовок 6 уровня
# ```

# %% [markdown]
# #### Ссылки

# %% [markdown]
# ``` Markdown
# [GitHub](https://github.com/)
# ```
#
# [GitHub](https://github.com/)

# %% [markdown]
# #### Списки
#
# Не нумерованный иерархический список
#
# * Элемент 1
# * Элемент 2
#     + Элемент 2 1
#     + Элемент 2 2
#         + Элемент 2 2 1
#         + Элемент 2 2 2
# * Элемент 3
#
# Нумерованные списки
#
# 1. Элемент 1
# 2. Элемент 2
# 3. Элемент 3

# %% [markdown]
# #### Цитаты
# > Если называть Python заменой BASIC, то тогда и трансформер Optimus Prime — это только замена грузовика.
# — Cory Dodt

# %% [markdown]
# #### Форматированный текст
#
# *курсив*
# _курсив_
#
# **жирный**
# __жирный__
#
# ***жирный курсив***
# ___жирный курсив___
#
# ~~зачеркнутый~~

# %% [markdown]
# #### Код
#
# ```Python
# df2 = pd.DataFrame(
#     {
#         "A": 1.0,
#         "B": pd.Timestamp("20130102"),
#         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
#         "D": np.array([3] * 4, dtype="int32"),
#         "E": pd.Categorical(["test", "train", "test", "train"]),
#         "F": "foo",
#     }
#
# )
# ```

# %% [markdown]
# ### Python (кодовые) ячейки

# %%
# Python код
x = [1,2,3,]
x # Результат выполнения последнего оператора выводится ниже ячейки
# Out:
# [1, 2, 3]

# %%
import pandas as pd
import numpy as np

df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }

)
df2 # DataFrame - выводится как таблица
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
from matplotlib import pyplot as plt 

x = [5, 2, 9, 4, 7] 
y = [10, 5, 8, 4, 2] 

plt.plot(x, y) 
plt.show() # Вывод графика
